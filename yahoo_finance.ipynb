# %%
import yfinance as yf

# %%
top_biotech_and_drugs = [
    "LLY",
    "NVO",
    "JNJ",
    "ABBV",
    "MRK",
    "RHHBY",
    "NVS",
    "AZN",
    "AMGN",
    "PFE",
    "SNY",
    "BMY",
    "VRTX",
    "GILD",
    "REGN",
    "ZTS",
    "GSK",
    "TAK",
    "HLN",
    "ARGX",
    "ALNY",
    "BNTX",
    "BIIB",
    "BGNE",
    "BAYRY",
    "TEVA",
    "UTHR",
    "VTRS",
    "RPRX",
    "MRNA",
]

# %%
multi_data = yf.download(top_biotech_and_drugs, period="5y", interval="1d")
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
multi_data.to_csv("biotech_5y_1d.csv")
